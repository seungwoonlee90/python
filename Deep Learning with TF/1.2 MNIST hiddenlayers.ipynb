# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
tf.random.set_seed(42)

# %%
epochs = 50
batch_size = 128
verbose = 1
nb_classes = 10
n_hidden = 128
validation_split = 0.2

# %%
mnist = keras.datasets.mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
print(X_train.shape, X_test.shape)
# Out:
# (60000, 28, 28) (10000, 28, 28)

# %%
reshaped = 784

X_train = X_train.reshape(60000, reshaped)
X_test = X_test.reshape(10000, reshaped)

# %%
X_train = X_train.astype(float)
X_test = X_test.astype(float)

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
y_train = tf.keras.utils.to_categorical(y_train, nb_classes)
y_test = tf.keras.utils.to_categorical(y_test, nb_classes)

# %%
model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(n_hidden,
                             input_shape=(reshaped,),
                             activation='relu'))
model.add(keras.layers.Dense(n_hidden,
                             activation='relu'))
model.add(keras.layers.Dense(nb_classes,
                             activation='softmax'))
# Out:
# 2022-03-16 16:07:35.776112: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-16 16:07:35.777156: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 8. Tune using inter_op_parallelism_threads for best performance.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='SGD', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=verbose,
          validation_split=validation_split)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/50
# 48000/48000 [==============================] - 3s 61us/sample - loss: 1.5053 - accuracy: 0.6144 - val_loss: 0.7790 - val_accuracy: 0.8322
# Epoch 2/50
# 48000/48000 [==============================] - 2s 48us/sample - loss: 0.6029 - accuracy: 0.8549 - val_loss: 0.4536 - val_accuracy: 0.8832
# Epoch 3/50
# 48000/48000 [==============================] - 2s 49us/sample - loss: 0.4320 - accuracy: 0.8858 - val_loss: 0.3707 - val_accuracy: 0.9003
# Epoch 4/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.3717 - accuracy: 0.8987 - val_loss: 0.3318 - val_accuracy: 0.9075
# Epoch 5/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.3391 - accuracy: 0.9054 - val_loss: 0.3084 - val_accuracy: 0.9138
# Epoch 6/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.3170 - accuracy: 0.9106 - val_loss: 0.2926 - val_accuracy: 0.9183
# Epoch 7/50
# 48000/48000 [==============================] - 2s 47us/sample - loss: 0.2999 - accuracy: 0.9145 - val_loss: 0.2795 - val_accuracy: 0.9204
# Epoch 8/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.2863 - accuracy: 0.9180 - val_loss: 0.2677 - val_accuracy: 0.9230
# Epoch 9/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.2744 - accuracy: 0.9206 - val_loss: 0.2587 - val_accuracy: 0.9255
# Epoch 10/50
# 48000/48000 [==============================] - 2s 47us/sample - loss: 0.2640 - accuracy: 0.9242 - val_loss: 0.2503 - val_accuracy: 0.9284
# Epoch 11/50
# 48000/48000 [==============================] - 2s 48us/sample - loss: 0.2546 - accuracy: 0.9267 - val_loss: 0.2435 - val_accuracy: 0.9298
# Epoch 12/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.2459 - accuracy: 0.9295 - val_loss: 0.2366 - val_accuracy: 0.9327
# Epoch 13/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.2378 - accuracy: 0.9317 - val_loss: 0.2293 - val_accuracy: 0.9343
# Epoch 14/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.2302 - accuracy: 0.9335 - val_loss: 0.2235 - val_accuracy: 0.9364
# Epoch 15/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.2232 - accuracy: 0.9361 - val_loss: 0.2186 - val_accuracy: 0.9383
# Epoch 16/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.2166 - accuracy: 0.9380 - val_loss: 0.2122 - val_accuracy: 0.9411
# Epoch 17/50
# 48000/48000 [==============================] - 2s 47us/sample - loss: 0.2103 - accuracy: 0.9398 - val_loss: 0.2080 - val_accuracy: 0.9408
# Epoch 18/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.2044 - accuracy: 0.9418 - val_loss: 0.2021 - val_accuracy: 0.9442
# Epoch 19/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.1984 - accuracy: 0.9439 - val_loss: 0.1973 - val_accuracy: 0.9453
# Epoch 20/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.1931 - accuracy: 0.9452 - val_loss: 0.1926 - val_accuracy: 0.9453
# Epoch 21/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.1879 - accuracy: 0.9469 - val_loss: 0.1905 - val_accuracy: 0.9458
# Epoch 22/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.1831 - accuracy: 0.9479 - val_loss: 0.1850 - val_accuracy: 0.9483
# Epoch 23/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.1785 - accuracy: 0.9493 - val_loss: 0.1817 - val_accuracy: 0.9503
# Epoch 24/50
# 48000/48000 [==============================] - 2s 47us/sample - loss: 0.1740 - accuracy: 0.9500 - val_loss: 0.1775 - val_accuracy: 0.9506
# Epoch 25/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.1700 - accuracy: 0.9516 - val_loss: 0.1748 - val_accuracy: 0.9525
# Epoch 26/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.1659 - accuracy: 0.9526 - val_loss: 0.1712 - val_accuracy: 0.9536
# Epoch 27/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.1618 - accuracy: 0.9544 - val_loss: 0.1689 - val_accuracy: 0.9541
# Epoch 28/50
# 48000/48000 [==============================] - 2s 49us/sample - loss: 0.1583 - accuracy: 0.9551 - val_loss: 0.1655 - val_accuracy: 0.9549
# Epoch 29/50
# 48000/48000 [==============================] - 2s 47us/sample - loss: 0.1548 - accuracy: 0.9564 - val_loss: 0.1625 - val_accuracy: 0.9559
# Epoch 30/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.1515 - accuracy: 0.9567 - val_loss: 0.1614 - val_accuracy: 0.9559
# Epoch 31/50
# 48000/48000 [==============================] - 2s 47us/sample - loss: 0.1481 - accuracy: 0.9579 - val_loss: 0.1593 - val_accuracy: 0.9566
# Epoch 32/50
# 48000/48000 [==============================] - 2s 47us/sample - loss: 0.1449 - accuracy: 0.9586 - val_loss: 0.1561 - val_accuracy: 0.9570
# Epoch 33/50
# 48000/48000 [==============================] - 2s 48us/sample - loss: 0.1420 - accuracy: 0.9600 - val_loss: 0.1537 - val_accuracy: 0.9577
# Epoch 34/50
# 48000/48000 [==============================] - 2s 47us/sample - loss: 0.1389 - accuracy: 0.9606 - val_loss: 0.1521 - val_accuracy: 0.9584
# Epoch 35/50
# 48000/48000 [==============================] - 2s 47us/sample - loss: 0.1363 - accuracy: 0.9612 - val_loss: 0.1492 - val_accuracy: 0.9589
# Epoch 36/50
# 48000/48000 [==============================] - 2s 48us/sample - loss: 0.1336 - accuracy: 0.9619 - val_loss: 0.1476 - val_accuracy: 0.9591
# Epoch 37/50
# 48000/48000 [==============================] - 2s 48us/sample - loss: 0.1309 - accuracy: 0.9632 - val_loss: 0.1452 - val_accuracy: 0.9602
# Epoch 38/50
# 48000/48000 [==============================] - 2s 48us/sample - loss: 0.1287 - accuracy: 0.9642 - val_loss: 0.1427 - val_accuracy: 0.9607
# Epoch 39/50
# 48000/48000 [==============================] - 2s 47us/sample - loss: 0.1261 - accuracy: 0.9641 - val_loss: 0.1418 - val_accuracy: 0.9611
# Epoch 40/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.1236 - accuracy: 0.9655 - val_loss: 0.1399 - val_accuracy: 0.9619
# Epoch 41/50
# 48000/48000 [==============================] - 2s 47us/sample - loss: 0.1214 - accuracy: 0.9656 - val_loss: 0.1384 - val_accuracy: 0.9619
# Epoch 42/50
# 48000/48000 [==============================] - 2s 49us/sample - loss: 0.1192 - accuracy: 0.9665 - val_loss: 0.1375 - val_accuracy: 0.9617
# Epoch 43/50
# 48000/48000 [==============================] - 2s 49us/sample - loss: 0.1171 - accuracy: 0.9668 - val_loss: 0.1364 - val_accuracy: 0.9617
# Epoch 44/50
# 48000/48000 [==============================] - 2s 47us/sample - loss: 0.1149 - accuracy: 0.9678 - val_loss: 0.1343 - val_accuracy: 0.9627
# Epoch 45/50
# 48000/48000 [==============================] - 3s 54us/sample - loss: 0.1130 - accuracy: 0.9679 - val_loss: 0.1324 - val_accuracy: 0.9630
# Epoch 46/50
# 48000/48000 [==============================] - 2s 50us/sample - loss: 0.1109 - accuracy: 0.9688 - val_loss: 0.1307 - val_accuracy: 0.9631
# Epoch 47/50
# 48000/48000 [==============================] - 2s 48us/sample - loss: 0.1091 - accuracy: 0.9695 - val_loss: 0.1306 - val_accuracy: 0.9637
# Epoch 48/50
# 48000/48000 [==============================] - 2s 48us/sample - loss: 0.1070 - accuracy: 0.9700 - val_loss: 0.1292 - val_accuracy: 0.9641
# Epoch 49/50
# 48000/48000 [==============================] - 2s 50us/sample - loss: 0.1054 - accuracy: 0.9702 - val_loss: 0.1268 - val_accuracy: 0.9650
# Epoch 50/50
# 48000/48000 [==============================] - 3s 53us/sample - loss: 0.1036 - accuracy: 0.9705 - val_loss: 0.1263 - val_accuracy: 0.9647

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test Accuracy', test_acc)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Test Accuracy 0.9645

# %% [markdown]
# ### Hidden Layers 의 추가로 인해 정확도 상승
# - Test Accuracy : from 0.9219 to 0.9645
