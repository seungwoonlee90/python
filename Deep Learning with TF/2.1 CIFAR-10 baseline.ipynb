# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import datasets, layers, models, optimizers

# %%
tf.random.set_seed(42)

# %%
img_channels = 3
img_rows = 32
img_cols =32

batch_size = 128
epochs = 20
classes = 10
verbose = 1
validation_split = 0.2
optimizer = tf.keras.optimizers.RMSprop()

# %%
def build(input_shape, classes) :
    model = models.Sequential()
    model.add(layers.Conv2D(32, (3,3), activation='relu', input_shape=input_shape))
    model.add(layers.MaxPooling2D(pool_size=(2,2)))
    model.add(layers.Dropout(0.25))
    
    model.add(layers.Flatten())
    model.add(layers.Dense(512, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(classes, activation='softmax'))
    return model

# %%
def load_data() :
    (X_train, y_train), (X_test, y_test) = datasets.cifar10.load_data()
    X_train = X_train.astype(float)
    X_test = X_test.astype(float)
    
    mean = np.mean(X_train, axis=(0,1,2,3))
    std = np.std(X_train, axis=(0,1,2,3))
    
    X_train = (X_train - mean) / (std+1e-7)
    X_test = (X_test - mean) / (std+1e-7)
    
    y_train = tf.keras.utils.to_categorical(y_train, classes)
    y_test = tf.keras.utils.to_categorical(y_test, classes)
    
    return X_train, y_train, X_test, y_test

# %%
X_train, y_train, X_test, y_test = load_data()

# %%
X_train.shape[1:]
# Out:
# (32, 32, 3)

# %%
model = build(X_train.shape[1:], classes)
# Out:
# 2022-03-18 16:44:55.081503: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-18 16:44:55.081992: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 8. Tune using inter_op_parallelism_threads for best performance.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 7200)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3686912
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 3,692,938
# Trainable params: 3,692,938
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=verbose,
                    validation_split=validation_split)
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/20
# 40000/40000 [==============================] - 68s 2ms/sample - loss: 1.6928 - accuracy: 0.4166 - val_loss: 1.3187 - val_accuracy: 0.5309
# Epoch 2/20
# 40000/40000 [==============================] - 66s 2ms/sample - loss: 1.2826 - accuracy: 0.5488 - val_loss: 1.2181 - val_accuracy: 0.5724
# Epoch 3/20
# 40000/40000 [==============================] - 65s 2ms/sample - loss: 1.1408 - accuracy: 0.5972 - val_loss: 1.0679 - val_accuracy: 0.6289
# Epoch 4/20
# 40000/40000 [==============================] - 65s 2ms/sample - loss: 1.0382 - accuracy: 0.6337 - val_loss: 1.0427 - val_accuracy: 0.6391
# Epoch 5/20
# 40000/40000 [==============================] - 65s 2ms/sample - loss: 0.9642 - accuracy: 0.6617 - val_loss: 1.0374 - val_accuracy: 0.6409
# Epoch 6/20
# 40000/40000 [==============================] - 65s 2ms/sample - loss: 0.9046 - accuracy: 0.6847 - val_loss: 1.0011 - val_accuracy: 0.6542
# Epoch 7/20
# 40000/40000 [==============================] - 65s 2ms/sample - loss: 0.8479 - accuracy: 0.7031 - val_loss: 0.9774 - val_accuracy: 0.6674
# Epoch 8/20
# 40000/40000 [==============================] - 65s 2ms/sample - loss: 0.8075 - accuracy: 0.7214 - val_loss: 0.9753 - val_accuracy: 0.6696
# Epoch 9/20
# 40000/40000 [==============================] - 65s 2ms/sample - loss: 0.7638 - accuracy: 0.7372 - val_loss: 0.9956 - val_accuracy: 0.6797
# Epoch 10/20
# 40000/40000 [==============================] - 65s 2ms/sample - loss: 0.7209 - accuracy: 0.7494 - val_loss: 0.9676 - val_accuracy: 0.6754
# Epoch 11/20
# 40000/40000 [==============================] - 65s 2ms/sample - loss: 0.6922 - accuracy: 0.7606 - val_loss: 0.9527 - val_accuracy: 0.6897
# Epoch 12/20
# 40000/40000 [==============================] - 66s 2ms/sample - loss: 0.6615 - accuracy: 0.7717 - val_loss: 0.9613 - val_accuracy: 0.6818
# Epoch 13/20
# 40000/40000 [==============================] - 64s 2ms/sample - loss: 0.6351 - accuracy: 0.7801 - val_loss: 1.0335 - val_accuracy: 0.6685
# Epoch 14/20
# 40000/40000 [==============================] - 64s 2ms/sample - loss: 0.6138 - accuracy: 0.7887 - val_loss: 1.0261 - val_accuracy: 0.6878
# Epoch 15/20
# 40000/40000 [==============================] - 64s 2ms/sample - loss: 0.5892 - accuracy: 0.7981 - val_loss: 0.9892 - val_accuracy: 0.6967
# Epoch 16/20
# 40000/40000 [==============================] - 65s 2ms/sample - loss: 0.5692 - accuracy: 0.8033 - val_loss: 0.9979 - val_accuracy: 0.6958
# Epoch 17/20
# 40000/40000 [==============================] - 64s 2ms/sample - loss: 0.5497 - accuracy: 0.8129 - val_loss: 1.0461 - val_accuracy: 0.6931
# Epoch 18/20
# 40000/40000 [==============================] - 64s 2ms/sample - loss: 0.5251 - accuracy: 0.8223 - val_loss: 1.0274 - val_accuracy: 0.6913
# Epoch 19/20
# 40000/40000 [==============================] - 64s 2ms/sample - loss: 0.5219 - accuracy: 0.8251 - val_loss: 1.0852 - val_accuracy: 0.6785
# Epoch 20/20
# 40000/40000 [==============================] - 64s 2ms/sample - loss: 0.5067 - accuracy: 0.8279 - val_loss: 1.0537 - val_accuracy: 0.6929

# %%
score = model.evaluate(X_test, y_test, verbose=verbose)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print('Test Accuracy', score[1])
# Out:
# Test Accuracy 0.6925
